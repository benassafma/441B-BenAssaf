# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv('/content/gdrive/MyDrive/ECON441B/EP.csv',parse_dates=True, index_col="DATE")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 397 entries, 1985-01-01 to 2018-01-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   397 non-null    float64
# dtypes: float64(1)
# memory usage: 6.2 KB

# %%
df.head()
# Out:
#               Value
# DATE
# 1985-01-01  72.5052
# 1985-02-01  70.6720
# 1985-03-01  62.4502
# 1985-04-01  57.4714
# 1985-05-01  55.3151

# %%
plt.figure(figsize = (10,5))
plt.plot(df['Value'])
plt.title('Energy Consumption from 1985 to 2018 in India')
plt.xlabel('Time')
plt.ylabel('Energy Consumption (GWatts)')
# Out:
# Text(0, 0.5, 'Energy Consumption')

# %%
## Energy Consumption in India in GigaWatts
